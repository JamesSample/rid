# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import nivapy3 as nivapy
import numpy as np
import pandas as pd
import seaborn as sn
import teotil2 as teo
import useful_rid_code as rid

sn.set_context("notebook")

# %% [markdown]
# # RID
#
# ## Estimating loads in unmonitored regions (parameterised)
#
# This notebook is "parameterised" for use with Papermill. The cell below has the tag `parameters`, which means the entire notebook can be called from `01_recalculate_ospar_1990-2016_main.ipynb`.
#
# The [TEOTIL2 model](https://nivanorge.github.io/teotil2/) is used to estimate loads in unmonitored areas. We know the regine ID for each of the 155 stations where water chemistry is measured, and we also know which OSPAR region each monitoring site drains to. We want to use observed data to estimate loads upstream of each monitoring point, and modelled data elsewhere.

# %%
# This cell is tagged 'parameters' for use with Papermill
# https://papermill.readthedocs.io/en/latest/index.html
year = 1990
user = ""
pw = ""

# %%
# Parameters
user = "jes"
pw = "BeakabusNov21.."
year = 2003

# %% [markdown]
# ## 1. Generate model input file

# %%
# Parameters of interest
par_list = ["Tot-N", "Tot-P"]

# Path to TEOTIL2 "core" input data
teo_fold = r"../../../teotil2/data/core_input_data"

# Ouput path for model file
ann_input_csv = f"../../../teotil2/data/norway_annual_input_data/input_data_{year}.csv"

# %%
engine = rid.connect_to_nivabase(user=user, pw=pw)
df = teo.io.make_input_file(
    year, engine, teo_fold, ann_input_csv, mode="nutrients", par_list=par_list
)
# Out:
# Connection successful.
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py:5176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %% [markdown]
# ## 2. Run model

# %%
# %%time

# Run model
g = teo.model.run_model(ann_input_csv)
# Out:
# /opt/conda/lib/python3.9/site-packages/teotil2/model.py:67: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated infavour of `both` or `neither`.
#   df[f"trans_{par}"].between(0, 1, inclusive=True).all()
# CPU times: user 6.2 s, sys: 96.2 ms, total: 6.29 s
# Wall time: 6.35 s

# %% [markdown]
# ## 3. Save results

# %%
# Save results as csv
res_csv = f"../../../teotil2/data/norway_annual_output_data/teotil2_results_{year}.csv"
df = teo.model.model_to_dataframe(g, out_path=res_csv)

df.head()
# Out:
#      regine regine_ned  accum_agri_diff_tot-n_tonnes  \
# 0  001.1A2B   001.1A2A                      2.649218
# 1  001.1A4D   001.1A4C                      0.000000
# 2    001.1M     001.1L                      0.000000
# 3  001.221Z   001.2210                      0.106883
# 4  001.222Z   001.2220                      0.880770
#
#    accum_agri_diff_tot-p_tonnes  accum_agri_pt_tot-n_tonnes  \
# 0                      0.174877                    0.033365
# 1                      0.000000                    0.000000
# 2                      0.000000                    0.000000
# 3                      0.007055                    0.001346
# 4                      0.058140                    0.011093
#
#    accum_agri_pt_tot-p_tonnes  accum_all_point_tot-n_tonnes  \
# 0                    0.002762                      0.285680
# 1                    0.000000                      0.000000
# 2                    0.000000                      0.000000
# 3                    0.000111                      0.011526
# 4                    0.000918                      0.094978
#
#    accum_all_point_tot-p_tonnes  accum_all_sources_tot-n_tonnes  \
# 0                      0.031371                       13.124639
# 1                      0.000000                        1.336510
# 2                      0.000000                        3.281474
# 3                      0.001266                        0.379687
# 4                      0.010430                        2.015410
#
#    accum_all_sources_tot-p_tonnes  ...  local_ren_tot-n_tonnes  \
# 0                        0.523642  ...                     0.0
# 1                        0.009101  ...                     0.0
# 2                        0.032868  ...                     0.0
# 3                        0.011237  ...                     0.0
# 4                        0.081465  ...                     0.0
#
#    local_ren_tot-p_tonnes  local_runoff_mm/yr  local_spr_tot-n_tonnes  \
# 0                     0.0          291.578599                0.252315
# 1                     0.0          340.175033                0.000000
# 2                     0.0          340.175033                0.000000
# 3                     0.0          291.578599                0.010180
# 4                     0.0          291.578599                0.083886
#
#    local_spr_tot-p_tonnes  local_trans_tot-n  local_trans_tot-p  \
# 0                0.028609               1.00               1.00
# 1                0.000000               0.81               0.26
# 2                0.000000               0.86               0.31
# 3                0.001154               1.00               1.00
# 4                0.009511               1.00               1.00
#
#    local_urban_tot-n_tonnes  local_urban_tot-p_tonnes  local_vol_lake_m3
# 0                   0.02205                   0.00315       1.788754e+08
# 1                   0.00000                   0.00000       8.019497e+06
# 2                   0.00000                   0.00000       3.866908e+07
# 3                   0.00000                   0.00000       0.000000e+00
# 4                   0.00000                   0.00000       0.000000e+00
#
# [5 rows x 54 columns]

# %%
# Save version with main catchments only
main_list = ["%03d." % i for i in range(1, 316)]
df2 = df.query("regine in @main_list")
df2.sort_values("regine", inplace=True)

# Save
main_csv = f"../../../Results/Unmon_loads/teotil2_results_{year}_main_catchs.csv"
df2.to_csv(main_csv, index=False, encoding="utf-8")
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %% [markdown]
# ## 4. Explore results
#
# ### 4.1. Total N and P
#
# ####  4.1.1. Identify areas with monitoring data
#
# Where observations are available, we want to use them in preference to the model output. This means identifying all the catchments with observed data and substracting the model results for these locations. This is more complicated than it appears, because a small number of observed catchments are upstream of others, so subtracting all the loads for the 155 monitored catchments involves "double accounting", which we want to avoid. The first step is therefore to identify the downstream-most nodes for the monitored areas i.e. for the cases where one catchment is upstream of another, we just want the downstream node.

# %%
# Read station data
in_xlsx = r"../../../Data/RID_Sites_List_2017-2020.xlsx"
stn_df = pd.read_excel(in_xlsx, sheet_name="RID_All")
stn_df = stn_df.query("station_id != 38005")  # Ignore TROEMÅL2

# Get just cols of interest and drop duplicates
# (some sites are in the same regine)
stn_df = stn_df[["ospar_region", "nve_vassdrag_nr"]].drop_duplicates()

# Get catch IDs with obs data
obs_nds = set(stn_df["nve_vassdrag_nr"].values)

# Build network from input file
g, nd_list = teo.calib.build_calib_network(ann_input_csv, obs_nds)

# Get list of downstream nodes
ds_nds = []
for nd in g:
    # If no downstream nodes
    if g.out_degree(nd) == 0:
        # Node is of interest
        ds_nds.append(nd)

# Get just the downstream catchments
stn_df = stn_df[stn_df["nve_vassdrag_nr"].isin(ds_nds)]

# %% [markdown]
# #### 4.1.2. Sum model results for monitored locations

# %%
# Read model output
teo_df = pd.read_csv(res_csv)

# Join accumulated outputs to stns of interest
mon_df = pd.merge(
    stn_df, teo_df, how="left", left_on="nve_vassdrag_nr", right_on="regine"
)

# Groupby OSPAR region
mon_df = mon_df.groupby("ospar_region").sum()

# Get just accum cols
cols = [i for i in mon_df.columns if i.split("_")[0] == "accum"]
mon_df = mon_df[cols]

mon_df.head()
# Out:
#                      accum_agri_diff_tot-n_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                    146.945306
# NORTH SEA                             2879.654602
# NORWEGIAN SEA2                        2914.744713
# SKAGERAK                             10810.336027
#
#                      accum_agri_diff_tot-p_tonnes  accum_agri_pt_tot-n_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                      4.979940                    2.540371
# NORTH SEA                               64.248040                   34.943085
# NORWEGIAN SEA2                          78.082751                   40.709881
# SKAGERAK                               215.849287                  102.034032
#
#                      accum_agri_pt_tot-p_tonnes  accum_all_point_tot-n_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                    0.213926                     95.626051
# NORTH SEA                              2.173150                    379.554813
# NORWEGIAN SEA2                         3.053550                    486.621924
# SKAGERAK                               5.504629                   3571.225861
#
#                      accum_all_point_tot-p_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                      6.527319
# NORTH SEA                               65.713194
# NORWEGIAN SEA2                          44.112110
# SKAGERAK                               130.932630
#
#                      accum_all_sources_tot-n_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                     3572.902199
# NORTH SEA                              10474.613249
# NORWEGIAN SEA2                         11180.051132
# SKAGERAK                               27523.760832
#
#                      accum_all_sources_tot-p_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                       55.726924
# NORTH SEA                                189.850888
# NORWEGIAN SEA2                           231.579285
# SKAGERAK                                 483.672673
#
#                      accum_anth_diff_tot-n_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                    146.945306
# NORTH SEA                             2885.627172
# NORWEGIAN SEA2                        2931.211691
# SKAGERAK                             10972.271266
#
#                      accum_anth_diff_tot-p_tonnes  ...  \
# ospar_region                                       ...
# LOFOTEN-BARENTS SEA                      4.979940  ...
# NORTH SEA                               64.791516  ...
# NORWEGIAN SEA2                          80.211901  ...
# SKAGERAK                               233.327049  ...
#
#                      accum_nat_diff_tot-n_tonnes  accum_nat_diff_tot-p_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                  3330.330843                    44.219664
# NORTH SEA                            7209.431264                    59.346179
# NORWEGIAN SEA2                       7762.217516                   107.255274
# SKAGERAK                            12980.263705                   119.412994
#
#                      accum_q_m3/s  accum_ren_tot-n_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA    776.552450               26.488625
# NORTH SEA              954.597136              153.668837
# NORWEGIAN SEA2        1445.310096              253.504396
# SKAGERAK              1574.386429             2223.190298
#
#                      accum_ren_tot-p_tonnes  accum_spr_tot-n_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                1.220114               66.597055
# NORTH SEA                         31.147775              146.828349
# NORWEGIAN SEA2                    20.680677              192.407647
# SKAGERAK                          31.143431              968.403271
#
#                      accum_spr_tot-p_tonnes  accum_upstr_area_km2  \
# ospar_region
# LOFOTEN-BARENTS SEA                5.093279              63555.61
# NORTH SEA                          9.376088              23353.19
# NORWEGIAN SEA2                    17.475327              45896.63
# SKAGERAK                          55.475384              93945.27
#
#                      accum_urban_tot-n_tonnes  accum_urban_tot-p_tonnes
# ospar_region
# LOFOTEN-BARENTS SEA                  0.000000                  0.000000
# NORTH SEA                            5.972570                  0.543476
# NORWEGIAN SEA2                      16.466978                  2.129151
# SKAGERAK                           161.935239                 17.477763
#
# [4 rows x 24 columns]

# %% [markdown]
# This table gives the **modelled** inputs to each OSPAR region from catchments for which we have observed data. We want to subtract these values from the overall modelled inputs to each region and substitute the observed data instead.
#
# The trickiest part of this is that the OSPAR regions in the TEOTIL catchment network (files named `regine_{year}.csv`) don't exactly match the relevant OSPAR definitions for this analysis. This is because the "OSPAR boundaries" in the model include catchments draining to Sweden (as part of TEOTIL2 Metals - see [here](https://nivanorge.github.io/teotil2/pages/07_1000_lakes.html)), so instead of using them directly we need to aggregate based on vassdragsnummers.

# %% [markdown]
# #### 4.1.3. Group model output according to "new" OSPAR regions

# %%
# Define "new" OSPAR regions (ranges are inclusive)
os_dict = {
    "SKAGERAK": (1, 23),
    "NORTH SEA": (24, 90),
    "NORWEGIAN SEA2": (91, 170),
    "LOFOTEN-BARENTS SEA": (171, 247),
}

# Container for results
df_list = []

# Loop over model output
for reg in os_dict.keys():
    min_id, max_id = os_dict[reg]

    regs = ["%03d." % i for i in range(min_id, max_id + 1)]

    # Get data for this region
    df2 = teo_df[teo_df["regine"].isin(regs)]

    # Get just accum cols
    cols = [i for i in df2.columns if i.split("_")[0] == "accum"]
    df2 = df2[cols]

    # Add region
    df2["ospar_region"] = reg

    # Add to output
    df_list.append(df2)

# Build df
os_df = pd.concat(df_list, axis=0)

# Aggregate
os_df = os_df.groupby("ospar_region").sum()

os_df.head()
# Out:
#                      accum_agri_diff_tot-n_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                    615.823635
# NORTH SEA                             6892.056526
# NORWEGIAN SEA2                        7889.739896
# SKAGERAK                             12423.357333
#
#                      accum_agri_diff_tot-p_tonnes  accum_agri_pt_tot-n_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                     25.552316                   10.569251
# NORTH SEA                              176.038926                   80.515432
# NORWEGIAN SEA2                         250.238821                  101.652087
# SKAGERAK                               276.089973                  112.948837
#
#                      accum_agri_pt_tot-p_tonnes  accum_all_point_tot-n_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                    0.866142                   6758.011589
# NORTH SEA                              5.832951                  12530.744580
# NORWEGIAN SEA2                         8.012104                  15116.645760
# SKAGERAK                               6.321836                   8310.363776
#
#                      accum_all_point_tot-p_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                   1260.217259
# NORTH SEA                             2200.392762
# NORWEGIAN SEA2                        2669.872828
# SKAGERAK                               319.259280
#
#                      accum_all_sources_tot-n_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                    15713.423523
# NORTH SEA                              34590.778229
# NORWEGIAN SEA2                         37545.273459
# SKAGERAK                               35095.418553
#
#                      accum_all_sources_tot-p_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                     1418.551964
# NORTH SEA                               2522.561119
# NORWEGIAN SEA2                          3137.610242
# SKAGERAK                                 759.512106
#
#                      accum_anth_diff_tot-n_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                    625.795944
# NORTH SEA                             6931.874008
# NORWEGIAN SEA2                        7921.898687
# SKAGERAK                             12697.091802
#
#                      accum_anth_diff_tot-p_tonnes  ...  \
# ospar_region                                       ...
# LOFOTEN-BARENTS SEA                     26.956157  ...
# NORTH SEA                              181.107596  ...
# NORWEGIAN SEA2                         254.479263  ...
# SKAGERAK                               308.821939  ...
#
#                      accum_nat_diff_tot-n_tonnes  accum_nat_diff_tot-p_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                  8329.615990                   131.378547
# NORTH SEA                           15128.159641                   141.060761
# NORWEGIAN SEA2                      14506.729012                   213.258151
# SKAGERAK                            14087.962975                   131.430888
#
#                      accum_q_m3/s  accum_ren_tot-n_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA   2156.261103              897.450238
# NORTH SEA             2108.513007             2606.102142
# NORWEGIAN SEA2        2867.740874             2182.154270
# SKAGERAK              1675.350005             5608.625628
#
#                      accum_ren_tot-p_tonnes  accum_spr_tot-n_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA              135.351470              308.045636
# NORTH SEA                        351.734617              692.804825
# NORWEGIAN SEA2                   301.334461              807.981945
# SKAGERAK                         111.281779             1179.857029
#
#                      accum_spr_tot-p_tonnes  accum_upstr_area_km2  \
# ospar_region
# LOFOTEN-BARENTS SEA               32.745660             138090.89
# NORTH SEA                         65.825025              59314.38
# NORWEGIAN SEA2                    88.401659             113934.05
# SKAGERAK                          76.818269             102574.69
#
#                      accum_urban_tot-n_tonnes  accum_urban_tot-p_tonnes
# ospar_region
# LOFOTEN-BARENTS SEA                  9.972310                  1.403841
# NORTH SEA                           39.817482                  5.068670
# NORWEGIAN SEA2                      32.158791                  4.240442
# SKAGERAK                           273.734469                 32.731966
#
# [4 rows x 24 columns]

# %% [markdown]
# We can now calculate the unmonitored component by simply subtracting the values modelled upstream of monitoring stations from the overall modelled inputs to each OSPAR region.
#
# #### 4.1.4. Estimate loads in unmonitored areas

# %%
# Calc unmonitored loads
unmon_df = os_df - mon_df

# Write output
out_csv = f"../../../Results/Unmon_loads/teotil2_raw_unmonitored_loads_{year}.csv"
unmon_df.to_csv(out_csv, encoding="utf-8", index_label="ospar_region")

unmon_df.round(0).astype(int).T
# Out:
# ospar_region                    LOFOTEN-BARENTS SEA  NORTH SEA  \
# accum_agri_diff_tot-n_tonnes                    469       4012
# accum_agri_diff_tot-p_tonnes                     21        112
# accum_agri_pt_tot-n_tonnes                        8         46
# accum_agri_pt_tot-p_tonnes                        1          4
# accum_all_point_tot-n_tonnes                   6662      12151
# accum_all_point_tot-p_tonnes                   1254       2135
# accum_all_sources_tot-n_tonnes                12141      24116
# accum_all_sources_tot-p_tonnes                 1363       2333
# accum_anth_diff_tot-n_tonnes                    479       4046
# accum_anth_diff_tot-p_tonnes                     22        116
# accum_aqu_tot-n_tonnes                         5542       8639
# accum_aqu_tot-p_tonnes                         1091       1703
# accum_ind_tot-n_tonnes                            0        468
# accum_ind_tot-p_tonnes                            0         51
# accum_nat_diff_tot-n_tonnes                    4999       7919
# accum_nat_diff_tot-p_tonnes                      87         82
# accum_q_m3/s                                   1380       1154
# accum_ren_tot-n_tonnes                          871       2452
# accum_ren_tot-p_tonnes                          134        321
# accum_spr_tot-n_tonnes                          241        546
# accum_spr_tot-p_tonnes                           28         56
# accum_upstr_area_km2                          74535      35961
# accum_urban_tot-n_tonnes                         10         34
# accum_urban_tot-p_tonnes                          1          5
#
# ospar_region                    NORWEGIAN SEA2  SKAGERAK
# accum_agri_diff_tot-n_tonnes              4975      1613
# accum_agri_diff_tot-p_tonnes               172        60
# accum_agri_pt_tot-n_tonnes                  61        11
# accum_agri_pt_tot-p_tonnes                   5         1
# accum_all_point_tot-n_tonnes             14630      4739
# accum_all_point_tot-p_tonnes              2626       188
# accum_all_sources_tot-n_tonnes           26365      7572
# accum_all_sources_tot-p_tonnes            2906       276
# accum_anth_diff_tot-n_tonnes              4991      1725
# accum_anth_diff_tot-p_tonnes               174        75
# accum_aqu_tot-n_tonnes                   11111        27
# accum_aqu_tot-p_tonnes                    2195         5
# accum_ind_tot-n_tonnes                     914      1105
# accum_ind_tot-p_tonnes                      74        81
# accum_nat_diff_tot-n_tonnes               6745      1108
# accum_nat_diff_tot-p_tonnes                106        12
# accum_q_m3/s                              1422       101
# accum_ren_tot-n_tonnes                    1929      3385
# accum_ren_tot-p_tonnes                     281        80
# accum_spr_tot-n_tonnes                     616       211
# accum_spr_tot-p_tonnes                      71        21
# accum_upstr_area_km2                     68037      8629
# accum_urban_tot-n_tonnes                    16       112
# accum_urban_tot-p_tonnes                     2        15

# %% [markdown]
# #### 4.1.5. Aggregate values to required quantities

# %%
# Aggregate to match report
unmon_df["flow"] = unmon_df["accum_q_m3/s"] * 60 * 60 * 24 / 1000.0  # 1000s m3/day

unmon_df["sew_n"] = (
    unmon_df["accum_ren_tot-n_tonnes"] + unmon_df["accum_spr_tot-n_tonnes"]
)
unmon_df["sew_p"] = (
    unmon_df["accum_ren_tot-p_tonnes"] + unmon_df["accum_spr_tot-p_tonnes"]
)

unmon_df["ind_n"] = unmon_df["accum_ind_tot-n_tonnes"]
unmon_df["ind_p"] = unmon_df["accum_ind_tot-p_tonnes"]

unmon_df["fish_n"] = unmon_df["accum_aqu_tot-n_tonnes"]
unmon_df["fish_p"] = unmon_df["accum_aqu_tot-p_tonnes"]

unmon_df["diff_n"] = (
    unmon_df["accum_anth_diff_tot-n_tonnes"] + unmon_df["accum_nat_diff_tot-n_tonnes"]
)
unmon_df["diff_p"] = (
    unmon_df["accum_anth_diff_tot-p_tonnes"] + unmon_df["accum_nat_diff_tot-p_tonnes"]
)

new_df = unmon_df[
    ["flow", "sew_n", "sew_p", "ind_n", "ind_p", "fish_n", "fish_p", "diff_n", "diff_p"]
]

# Total for Norway
new_df.loc["NORWAY"] = new_df.sum(axis=0)

# Reorder rows
new_df = new_df.reindex(
    ["NORWAY", "LOFOTEN-BARENTS SEA", "NORTH SEA", "NORWEGIAN SEA2", "SKAGERAK"]
)

new_df.round().astype(int)
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                        flow  sew_n  sew_p  ind_n  ind_p  fish_n  fish_p  \
# ospar_region
# NORWAY               350526  10252    992   2486    206   25319    4994
# LOFOTEN-BARENTS SEA  119207   1112    162      0      0    5542    1091
# NORTH SEA             99698   2998    377    468     51    8639    1703
# NORWEGIAN SEA2       122898   2544    352    914     74   11111    2195
# SKAGERAK               8723   3597    101   1105     81      27       5
#
#                      diff_n  diff_p
# ospar_region
# NORWAY                32011     675
# LOFOTEN-BARENTS SEA    5478     109
# NORTH SEA             11965     198
# NORWEGIAN SEA2        11735     280
# SKAGERAK               2833      88

# %% [markdown]
# ## 5. Other N and P species
#
# Tore's procedure `RESA2.FIXTEOTILPN` defines simple correction factors for estimating PO4, NO3 and NH4 from total P and N. The table below lists the factors used.
#
# |   Source    | Phosphate | Nitrate | Ammonium |
# |:-----------:|:---------:|:-------:|:--------:|
# |    Sewage   |     0.600 |   0.050 |    0.750 |
# |   Industry  |     0.600 |   0.050 |    0.750 |
# | Aquaculture |     0.690 |   0.110 |    0.800 |
# |   Diffuse   |     0.246 |   0.625 |    0.055 |

# %%
# Dict of conversion factors
con_dict = {
    ("sew", "po4"): ("p", 0.6),
    ("ind", "po4"): ("p", 0.6),
    ("fish", "po4"): ("p", 0.69),
    ("diff", "po4"): ("p", 0.246),
    ("sew", "no3"): ("n", 0.05),
    ("ind", "no3"): ("n", 0.05),
    ("fish", "no3"): ("n", 0.11),
    ("diff", "no3"): ("n", 0.625),
    ("sew", "nh4"): ("n", 0.75),
    ("ind", "nh4"): ("n", 0.75),
    ("fish", "nh4"): ("n", 0.8),
    ("diff", "nh4"): ("n", 0.055),
}

# Apply factors
for src in ["sew", "ind", "fish", "diff"]:
    for spc in ["po4", "no3", "nh4"]:
        el, fac = con_dict[(src, spc)]
        new_df[src + "_" + spc] = fac * new_df[src + "_" + el]

new_df.round().astype(int).T
# Out:
# ospar_region  NORWAY  LOFOTEN-BARENTS SEA  NORTH SEA  NORWEGIAN SEA2  SKAGERAK
# flow          350526               119207      99698          122898      8723
# sew_n          10252                 1112       2998            2544      3597
# sew_p            992                  162        377             352       101
# ind_n           2486                    0        468             914      1105
# ind_p            206                    0         51              74        81
# fish_n         25319                 5542       8639           11111        27
# fish_p          4994                 1091       1703            2195         5
# diff_n         32011                 5478      11965           11735      2833
# diff_p           675                  109        198             280        88
# sew_po4          595                   97        226             211        61
# sew_no3          513                   56        150             127       180
# sew_nh4         7689                  834       2249            1908      2698
# ind_po4          124                    0         30              45        49
# ind_no3          124                    0         23              46        55
# ind_nh4         1865                    0        351             685       828
# fish_po4        3446                  753       1175            1515         4
# fish_no3        2785                  610        950            1222         3
# fish_nh4       20255                 4434       6912            8889        21
# diff_po4         166                   27         49              69        22
# diff_no3       20007                 3424       7478            7334      1770
# diff_nh4        1761                  301        658             645       156

# %% [markdown]
# ## 6. Other quantities
#
# The model currently only considers N and P, but the project focuses on a wider range of parameters. For now, we simply assume that all measured inputs (`renseanlegg`, `industri` and `akvakultur`) for regines outside of catchments with measured data make it to the sea.
#
# We only want data for catchments that are not monitored i.e. for regine IDs **not** in the graph created above.

# %%
engine = rid.connect_to_nivabase(user=user, pw=pw)

# The sql below uses a horrible (and slow!) hack to get around Oracle's
# 1000 item limit on IN clauses. See here for details:
# https://stackoverflow.com/a/9084247/505698
nd_list_hack = [(1, i) for i in nd_list]

sql = (
    "SELECT SUBSTR(a.regine, 1, 3) AS vassdrag, "
    "  a.type, "
    "  b.name, "
    "  b.unit, "
    "  SUM(c.value * d.factor) as value "
    "FROM RESA2.RID_PUNKTKILDER a, "
    "RESA2.RID_PUNKTKILDER_OUTPAR_DEF b, "
    "RESA2.RID_PUNKTKILDER_INPAR_VALUES c, "
    "RESA2.RID_PUNKTKILDER_INP_OUTP d "
    "WHERE a.anlegg_nr = c.anlegg_nr "
    "AND (1, a.regine) NOT IN %s "
    "AND d.in_pid = c.inp_par_id "
    "AND d.out_pid = b.out_pid "
    "AND c.year = %s "
    "GROUP BY SUBSTR(a.regine, 1, 3), a.type, b.name, b.unit "
    "ORDER BY SUBSTR(a.regine, 1, 3), a.type" % (tuple(nd_list_hack), year)
)

df = pd.read_sql(sql, engine)

# Tidy
df["par"] = df["type"] + "_" + df["name"] + "_" + df["unit"]
del df["name"], df["unit"], df["type"]

# Pivot
df = df.pivot(index="vassdrag", columns="par", values="value")
df.reset_index(inplace=True)
# Out:
# Connection successful.

# %%
def f(x):
    try:
        a = int(x)
        return a
    except:
        return -999


# Convert vassdrag to numbers
df["vass"] = df["vassdrag"].apply(f)

# Get just the main catchments
df = df.query("vass != -999")

df.head()
# Out:
# par vassdrag  INDUSTRI_As_tonn  INDUSTRI_Cd_tonn  INDUSTRI_Cr_tonn  \
# 0          0               NaN               NaN               NaN
# 1        001               NaN               NaN               NaN
# 2        002             0.052            0.0046            0.0019
# 3        003               NaN               NaN               NaN
# 4        004               NaN               NaN               NaN
#
# par  INDUSTRI_Cu_tonn  INDUSTRI_Hg_tonn  INDUSTRI_NH3_tonn  \
# 0                 NaN               NaN                NaN
# 1            0.000010               NaN                NaN
# 2            6.805564           0.00551                NaN
# 3                 NaN               NaN                NaN
# 4                 NaN               NaN                NaN
#
# par  INDUSTRI_NH4-N_tonn  INDUSTRI_Ni_tonn  INDUSTRI_Pb_tonn  ...  \
# 0                    NaN               NaN               NaN  ...
# 1                    NaN               NaN               NaN  ...
# 2                    NaN          0.259218          0.043406  ...
# 3                    NaN               NaN               NaN  ...
# 4                    NaN               NaN               NaN  ...
#
# par  RENSEANLEGG_Hg_tonn  RENSEANLEGG_Ni_tonn  RENSEANLEGG_PAH_tonn  \
# 0                    NaN                  NaN                   NaN
# 1                    NaN                  NaN                   NaN
# 2                0.00260                0.074                   NaN
# 3                    NaN                  NaN                   NaN
# 4                0.00118                0.054                   NaN
#
# par  RENSEANLEGG_Pb_tonn  RENSEANLEGG_S.P.M._tonn  RENSEANLEGG_TOC_tonn  \
# 0                    NaN                      NaN                   NaN
# 1                    NaN                      NaN                   NaN
# 2                   0.02                      NaN               340.853
# 3                    NaN                      NaN                66.949
# 4                   0.07                      NaN                   NaN
#
# par  RENSEANLEGG_Tot-N_tonn  RENSEANLEGG_Tot-P_tonn  RENSEANLEGG_Zn_tonn  vass
# 0                  5.482008                0.730292                  NaN     0
# 1                 87.346270                1.938920                  NaN     1
# 2                322.437680                8.804160                1.084     2
# 3                208.093010                2.332190                  NaN     3
# 4                 65.889760                1.300830                0.727     4
#
# [5 rows x 28 columns]

# %%
def f2(x):
    if x in range(1, 24):
        return "SKAGERAK"
    elif x in range(24, 91):
        return "NORTH SEA"
    elif x in range(91, 171):
        return "NORWEGIAN SEA2"
    elif x in range(171, 248):
        return "LOFOTEN-BARENTS SEA"
    else:
        return np.nan


# Assign main catchments to OSPAR regions
df["osp_reg"] = df["vass"].apply(f2)

df.head()
# Out:
# par vassdrag  INDUSTRI_As_tonn  INDUSTRI_Cd_tonn  INDUSTRI_Cr_tonn  \
# 0          0               NaN               NaN               NaN
# 1        001               NaN               NaN               NaN
# 2        002             0.052            0.0046            0.0019
# 3        003               NaN               NaN               NaN
# 4        004               NaN               NaN               NaN
#
# par  INDUSTRI_Cu_tonn  INDUSTRI_Hg_tonn  INDUSTRI_NH3_tonn  \
# 0                 NaN               NaN                NaN
# 1            0.000010               NaN                NaN
# 2            6.805564           0.00551                NaN
# 3                 NaN               NaN                NaN
# 4                 NaN               NaN                NaN
#
# par  INDUSTRI_NH4-N_tonn  INDUSTRI_Ni_tonn  INDUSTRI_Pb_tonn  ...  \
# 0                    NaN               NaN               NaN  ...
# 1                    NaN               NaN               NaN  ...
# 2                    NaN          0.259218          0.043406  ...
# 3                    NaN               NaN               NaN  ...
# 4                    NaN               NaN               NaN  ...
#
# par  RENSEANLEGG_Ni_tonn  RENSEANLEGG_PAH_tonn  RENSEANLEGG_Pb_tonn  \
# 0                    NaN                   NaN                  NaN
# 1                    NaN                   NaN                  NaN
# 2                  0.074                   NaN                 0.02
# 3                    NaN                   NaN                  NaN
# 4                  0.054                   NaN                 0.07
#
# par  RENSEANLEGG_S.P.M._tonn  RENSEANLEGG_TOC_tonn  RENSEANLEGG_Tot-N_tonn  \
# 0                        NaN                   NaN                5.482008
# 1                        NaN                   NaN               87.346270
# 2                        NaN               340.853              322.437680
# 3                        NaN                66.949              208.093010
# 4                        NaN                   NaN               65.889760
#
# par  RENSEANLEGG_Tot-P_tonn  RENSEANLEGG_Zn_tonn  vass   osp_reg
# 0                  0.730292                  NaN     0       NaN
# 1                  1.938920                  NaN     1  SKAGERAK
# 2                  8.804160                1.084     2  SKAGERAK
# 3                  2.332190                  NaN     3  SKAGERAK
# 4                  1.300830                0.727     4  SKAGERAK
#
# [5 rows x 29 columns]

# %%
# Group by OSPAR region
df.fillna(0, inplace=True)
df = df.groupby("osp_reg").sum()
if 0 in df.index:
    df.drop(0, inplace=True)

# Total for Norway
df.loc["NORWAY"] = df.sum(axis=0)

# Join to model results
df = new_df.join(df)

# Get cols of interest
umod_cols = ["S.P.M.", "TOC", "As", "Pb", "Cd", "Cu", "Zn", "Ni", "Cr", "Hg"]
umod_cols = [
    "%s_%s_tonn" % (i, j) for i in ["INDUSTRI", "RENSEANLEGG"] for j in umod_cols
]
cols = list(new_df.columns) + umod_cols
cols.remove("RENSEANLEGG_TOC_tonn")
cols = [i for i in cols if i in df.columns]
df = df[cols]

df.round(0).astype(int).T
# Out:
# ospar_region             NORWAY  LOFOTEN-BARENTS SEA  NORTH SEA  \
# flow                     350526               119207      99698
# sew_n                     10252                 1112       2998
# sew_p                       992                  162        377
# ind_n                      2486                    0        468
# ind_p                       206                    0         51
# fish_n                    25319                 5542       8639
# fish_p                     4994                 1091       1703
# diff_n                    32011                 5478      11965
# diff_p                      675                  109        198
# sew_po4                     595                   97        226
# sew_no3                     513                   56        150
# sew_nh4                    7689                  834       2249
# ind_po4                     124                    0         30
# ind_no3                     124                    0         23
# ind_nh4                    1865                    0        351
# fish_po4                   3446                  753       1175
# fish_no3                   2785                  610        950
# fish_nh4                  20255                 4434       6912
# diff_po4                    166                   27         49
# diff_no3                  20007                 3424       7478
# diff_nh4                   1761                  301        658
# INDUSTRI_S.P.M._tonn     657231               225731       8875
# INDUSTRI_TOC_tonn           369                    0        207
# INDUSTRI_As_tonn              1                    1          0
# INDUSTRI_Pb_tonn              3                    1          2
# INDUSTRI_Cd_tonn              0                    0          0
# INDUSTRI_Cu_tonn              8                    0          1
# INDUSTRI_Zn_tonn             16                    2         13
# INDUSTRI_Ni_tonn             10                    1          7
# INDUSTRI_Cr_tonn              0                    0          0
# INDUSTRI_Hg_tonn              0                    0          0
# RENSEANLEGG_S.P.M._tonn    6759                    5        256
# RENSEANLEGG_Pb_tonn           0                    0          0
# RENSEANLEGG_Cd_tonn           0                    0          0
# RENSEANLEGG_Cu_tonn           3                    0          0
# RENSEANLEGG_Zn_tonn          10                    0          0
# RENSEANLEGG_Ni_tonn           1                    0          0
# RENSEANLEGG_Cr_tonn           1                    0          0
# RENSEANLEGG_Hg_tonn           0                    0          0
#
# ospar_region             NORWEGIAN SEA2  SKAGERAK
# flow                             122898      8723
# sew_n                              2544      3597
# sew_p                               352       101
# ind_n                               914      1105
# ind_p                                74        81
# fish_n                            11111        27
# fish_p                             2195         5
# diff_n                            11735      2833
# diff_p                              280        88
# sew_po4                             211        61
# sew_no3                             127       180
# sew_nh4                            1908      2698
# ind_po4                              45        49
# ind_no3                              46        55
# ind_nh4                             685       828
# fish_po4                           1515         4
# fish_no3                           1222         3
# fish_nh4                           8889        21
# diff_po4                             69        22
# diff_no3                           7334      1770
# diff_nh4                            645       156
# INDUSTRI_S.P.M._tonn             420663      1961
# INDUSTRI_TOC_tonn                    57       104
# INDUSTRI_As_tonn                      0         1
# INDUSTRI_Pb_tonn                      0         0
# INDUSTRI_Cd_tonn                      0         0
# INDUSTRI_Cu_tonn                      0         8
# INDUSTRI_Zn_tonn                      0         1
# INDUSTRI_Ni_tonn                      0         2
# INDUSTRI_Cr_tonn                      0         0
# INDUSTRI_Hg_tonn                      0         0
# RENSEANLEGG_S.P.M._tonn            4793      1705
# RENSEANLEGG_Pb_tonn                   0         0
# RENSEANLEGG_Cd_tonn                   0         0
# RENSEANLEGG_Cu_tonn                   0         3
# RENSEANLEGG_Zn_tonn                   0        10
# RENSEANLEGG_Ni_tonn                   0         1
# RENSEANLEGG_Cr_tonn                   0         1
# RENSEANLEGG_Hg_tonn                   0         0

# %% [markdown]
# ## 7. Fish farm copper
#
# Finally, we need to add in the Cu totals from fish farms. The method is similar to that used above, but simpler because we're only interested in one parameter.

# %%
engine = rid.connect_to_nivabase(user=user, pw=pw)

# The sql below uses a horrible (and slow!) hack to get around Oracle's
# 1000 item limit on IN clauses. See here for details:
# https://stackoverflow.com/a/9084247/505698
nd_list_hack = [(1, i) for i in nd_list]

sql = (
    "SELECT SUBSTR(regine, 1, 3) AS vassdrag, "
    "  SUM(value) AS value FROM ( "
    "    SELECT b.regine, "
    "           c.name, "
    "           (a.value*d.factor) AS value "
    "    FROM resa2.rid_kilder_aqkult_values a, "
    "    resa2.rid_kilder_aquakultur b, "
    "    resa2.rid_punktkilder_outpar_def c, "
    "    resa2.rid_punktkilder_inp_outp d "
    "    WHERE a.anlegg_nr = b.nr "
    "    AND (1, b.regine) NOT IN %s "
    "    AND a.inp_par_id = d.in_pid "
    "    AND c.out_pid = d.out_pid "
    "    AND name = 'Cu' "
    "    AND ar = %s) "
    "GROUP BY SUBSTR(regine, 1, 3)" % (tuple(nd_list_hack), year)
)

aq_df = pd.read_sql(sql, engine)

if len(aq_df) > 0:
    # Get vassdrag
    aq_df["vass"] = aq_df["vassdrag"].apply(f)
    aq_df = aq_df.query("vass != -999")

    # Calc OSPAR region and group
    aq_df["osp_reg"] = aq_df["vass"].apply(f2)
    aq_df.fillna(0, inplace=True)
    aq_df = aq_df.groupby("osp_reg").sum()
    del aq_df["vass"]

    # Total for Norway
    aq_df.loc["NORWAY"] = aq_df.sum(axis=0)

    # Rename
    aq_df.columns = [
        "AQUAKULTUR_Cu_tonn",
    ]

    # Join model results
    df = df.join(aq_df)

    df.round(0).astype(int).T
# Out:
# Connection successful.

# %%
# Write output
out_csv = f"../../../Results/Unmon_loads/teotil2_ospar_unmonitored_loads_{year}.csv"
df.to_csv(out_csv)

# %% [markdown]
# This data can then be used to create Table 3 in the report - see [this notebook](https://nbviewer.jupyter.org/github/JamesSample/rid/blob/master/notebooks/summary_table_2017.ipynb) for details.
