# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import imp

sn.set_context('notebook')

# %% [markdown]
# # Estimating loads in unmonitored regions - 2016
#
# The output from the new model can be used to estimate loads in unmonitored areas. We know the regine ID for each of the 155 stations where water chemistry is measured, and we also know which OSPAR region each monitoring site drains to. We want to use observed data to estimate loads upstream of each monitoring point, and modelled data elsewhere. This can easily be achieved using the output from the new model.
#
# **Note:** In the code below, I'm assuming that we want to use the observed data for all 155 sites. In reality, values for the `RID_108` stations are estimated using linear interpolation, so we may prefer to use the modelled output for these anyway. Furthermore, in the OSPAR template we only report observed values for the 11 main rivers. The choice of which sites to consider "observed" can easily be controlled by reading different sheet(s) into `stn_df` in the code below.

# %%
# Import model
nope_path = (r'C:\Data\James_Work\Staff\Oeyvind_K\Elveovervakingsprogrammet'
             r'\Python\rid\notebooks\nope.py')
nope = imp.load_source('nope', nope_path)

# Connect to db
resa2_basic_path = (r'C:\Data\James_Work\Staff\Heleen_d_W\ICP_Waters\Upload_Template'
                    r'\useful_resa2_code.py')
resa2_basic = imp.load_source('useful_resa2_code', resa2_basic_path)
engine, conn = resa2_basic.connect_to_resa2()

# %% [markdown]
# ## 1. Generate model input file

# %%
# Year of interest
year = 2016

# Parameters of interest
par_list = ['Tot-N', 'Tot-P']

# Folder containing NOPE data
nope_fold = (r'C:\Data\James_Work\Staff\Oeyvind_K\Elveovervakingsprogrammet'
             r'\NOPE\NOPE_Core_Input_Data')

# Ouput path for model file
out_csv = (r'C:\Data\James_Work\Staff\Oeyvind_K\Elveovervakingsprogrammet'
           r'\NOPE\NOPE_Annual_Inputs\nope_input_data_2016.csv')

# %%
# Make input file
df = nope.make_rid_input_file(year, engine, nope_fold, out_csv,
                              par_list=par_list)
# Out:
# C:\Data\WinPython-64bit-2.7.10.3\python-2.7.10.amd64\lib\site-packages\pandas\core\frame.py:2842: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)

# %% [markdown]
# ## 2. Run model

# %%
# %%time
# Input file
in_csv = (r'C:\Data\James_Work\Staff\Oeyvind_K\Elveovervakingsprogrammet'
          r'\NOPE\NOPE_Annual_Inputs\nope_input_data_2016.csv')

# Run model
g = nope.run_nope(in_csv, par_list)
# Out:
# Wall time: 4.2 s

# %% [markdown]
# ## 3. Save results

# %%
# Save results as csv
out_csv = (r'C:\Data\James_Work\Staff\Oeyvind_K\Elveovervakingsprogrammet'
           r'\NOPE\nope_results_2016.csv')
df = nope.model_to_dataframe(g, out_path=out_csv)

df.head()
# Out:
#      regine regine_ned  accum_all_point_tot-n_tonnes  \
# 0  001.222Z   001.2220                      0.109003
# 1  002.DGBZ   002.DGB0                      0.000000
# 2   123.A1Z    123.A12                      0.484875
# 3   212.FAC   212.FAB0                      0.021639
# 4   135.1AC    135.1AB                      0.000000
#
#    accum_all_point_tot-p_tonnes  accum_all_sources_tot-n_tonnes  \
# 0                      0.007512                        2.014422
# 1                      0.000000                        5.077570
# 2                      0.023375                       16.146657
# 3                      0.000779                        7.536223
# 4                      0.000000                        4.721225
#
#    accum_all_sources_tot-p_tonnes  accum_anth_diff_tot-n_tonnes  \
# 0                        0.078850                      0.930145
# 1                        0.108752                      0.000000
# 2                        0.311826                     11.213173
# 3                        0.076501                      0.000000
# 4                        0.049250                      0.000000
#
#    accum_anth_diff_tot-p_tonnes  accum_aqu_tot-n_tonnes  \
# 0                      0.058948                     0.0
# 1                      0.000000                     0.0
# 2                      0.249968                     0.0
# 3                      0.000000                     0.0
# 4                      0.000000                     0.0
#
#    accum_aqu_tot-p_tonnes        ...          local_nat_diff_tot-n_tonnes  \
# 0                     0.0        ...                             0.975274
# 1                     0.0        ...                             5.234608
# 2                     0.0        ...                             5.492109
# 3                     0.0        ...                             7.910089
# 4                     0.0        ...                             5.554382
#
#    local_nat_diff_tot-p_tonnes  local_q_reg_m3/s  local_ren_tot-n_tonnes  \
# 0                     0.012389          0.052966                     0.0
# 1                     0.131027          0.780749                     0.0
# 2                     0.128275          0.624774                     0.0
# 3                     0.099634          0.561737                     0.0
# 4                     0.117261          0.880246                     0.0
#
#    local_ren_tot-p_tonnes  local_runoff_mm/yr  local_spr_tot-n_tonnes  \
# 0                     0.0          268.974615                0.097939
# 1                     0.0          286.099189                0.000000
# 2                     0.0          494.426247                0.444984
# 3                     0.0          325.881795                0.022777
# 4                     0.0         1975.761038                0.000000
#
#    local_spr_tot-p_tonnes  local_trans_tot-n  local_trans_tot-p
# 0                0.006618               1.00               1.00
# 1                0.000000               0.97               0.83
# 2                0.064271               0.81               0.30
# 3                0.001025               0.95               0.76
# 4                0.000000               0.85               0.42
#
# [5 rows x 41 columns]

# %% [markdown]
# ## 4. Explore results

# %%
# Read model output
in_csv = (r'C:\Data\James_Work\Staff\Oeyvind_K\Elveovervakingsprogrammet'
          r'\NOPE\nope_results_2016.csv')
nope_df = pd.read_csv(in_csv)

# Read station data
in_xlsx = (r'C:\Data\James_Work\Staff\Oeyvind_K\Elveovervakingsprogrammet'
           r'\Data\RID_Sites_List.xlsx')
stn_df = pd.read_excel(in_xlsx, sheetname='RID_All')

# Join accumulated outputs to stns
mon_df = pd.merge(stn_df, nope_df, how='left',
                  left_on='nve_vassdrag_nr',
                  right_on='regine')

# Groupby OSPAR region
mon_df = mon_df.groupby('ospar_region').sum()

# Get just accum cols
cols = [i for i in mon_df.columns if i.split('_')[0]=='accum']
mon_df = mon_df[cols]

mon_df.head()
# Out:
#                      accum_all_point_tot-n_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                     77.940831
# NORTH SEA                              427.423604
# NORWEGIAN SEA2                         628.328294
# SKAGERAK                              3798.995861
#
#                      accum_all_point_tot-p_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                      5.693310
# NORTH SEA                               40.717570
# NORWEGIAN SEA2                          56.047081
# SKAGERAK                               108.787370
#
#                      accum_all_sources_tot-n_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                     4291.217530
# NORTH SEA                              13738.091623
# NORWEGIAN SEA2                         12422.700767
# SKAGERAK                               30191.714572
#
#                      accum_all_sources_tot-p_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                       61.556413
# NORTH SEA                                204.622091
# NORWEGIAN SEA2                           260.046138
# SKAGERAK                                 487.862844
#
#                      accum_anth_diff_tot-n_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                    139.951511
# NORTH SEA                             2656.367698
# NORWEGIAN SEA2                        2945.949040
# SKAGERAK                             11150.240482
#
#                      accum_anth_diff_tot-p_tonnes  accum_aqu_tot-n_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                      5.259556                     0.0
# NORTH SEA                               70.932435                     0.0
# NORWEGIAN SEA2                          82.039630                     0.0
# SKAGERAK                               245.101403                     0.0
#
#                      accum_aqu_tot-p_tonnes  accum_ind_tot-n_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                     0.0                0.000000
# NORTH SEA                               0.0               25.603844
# NORWEGIAN SEA2                          0.0               46.041830
# SKAGERAK                                0.0              182.085191
#
#                      accum_ind_tot-p_tonnes  accum_nat_diff_tot-n_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                0.000000                  4073.325188
# NORTH SEA                          3.641174                 10654.300321
# NORWEGIAN SEA2                    10.443500                  8848.423433
# SKAGERAK                          26.602975                 15242.478230
#
#                      accum_nat_diff_tot-p_tonnes  accum_q_m3/s  \
# ospar_region
# LOFOTEN-BARENTS SEA                    50.603547    897.263854
# NORTH SEA                              92.972086   1668.654210
# NORWEGIAN SEA2                        121.959428   1656.251067
# SKAGERAK                              133.974070   2021.680980
#
#                      accum_ren_tot-n_tonnes  accum_ren_tot-p_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA               24.647655                0.757696
# NORTH SEA                        232.564816               24.008028
# NORWEGIAN SEA2                   327.090573               19.868830
# SKAGERAK                        2641.158801               24.549411
#
#                      accum_spr_tot-n_tonnes  accum_spr_tot-p_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA               50.753621                4.717238
# NORTH SEA                        133.403434               10.804017
# NORWEGIAN SEA2                   209.966091               22.408039
# SKAGERAK                         873.645037               52.085883
#
#                      accum_upstr_area_km2
# ospar_region
# LOFOTEN-BARENTS SEA              63555.61
# NORTH SEA                        25223.53
# NORWEGIAN SEA2                   49150.49
# SKAGERAK                         94172.25

# %% [markdown]
# This table gives the **modelled** inputs to each OSPAR region from catchments for which we have observed data. We want to subtract these values from the overall modelled inputs to each region and substitute the observed data instead.
#
# The trickiest part of this is that the OSPAR regions in the TEOTIL catchment network (and therefore the network for my new model too) don't exactly match the new OSPAR definitions. The OSPAR boundaries were updated relatively recently, so instead of simply selecting the desired OSPAR region in the model output, I need to aggregate based on vassdragsnummers.

# %%
# Define "new" OSPAR regions
os_dict = {'SKAGERAK':(1, 23),
           'NORTH SEA':(24, 90),
           'NORWEGIAN SEA2':(91, 170),
           'LOFOTEN-BARENTS SEA':(171, 247)}

# Container for results
df_list = []

# Loop over model output
for reg in os_dict.keys():
    min_id, max_id = os_dict[reg]
    
    regs = ['%03d.' % i for i in range(min_id, max_id+1)]
    
    # Get data for this region
    df2 = nope_df[nope_df['regine'].isin(regs)]
    
    # Get just accum cols
    cols = [i for i in df2.columns if i.split('_')[0]=='accum']
    df2 = df2[cols]
    
    # Add region
    df2['ospar_region'] = reg
    
    # Add sum to output
    df_list.append(df2)

# Build df
os_df = pd.concat(df_list, axis=0)

# Aggregate
os_df = os_df.groupby('ospar_region').sum()

os_df.head()
# Out:
#                      accum_all_point_tot-n_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                  15536.465083
# NORTH SEA                            24154.765441
# NORWEGIAN SEA2                       27414.085643
# SKAGERAK                             10555.596638
#
#                      accum_all_point_tot-p_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                   2624.071894
# NORTH SEA                             3943.734990
# NORWEGIAN SEA2                        4530.286265
# SKAGERAK                               274.680733
#
#                      accum_all_sources_tot-n_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                    24729.268966
# NORTH SEA                              51360.258258
# NORWEGIAN SEA2                         50838.865740
# SKAGERAK                               39811.418034
#
#                      accum_all_sources_tot-p_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                     2782.102006
# NORTH SEA                               4337.303801
# NORWEGIAN SEA2                          5002.845199
# SKAGERAK                                 741.044808
#
#                      accum_anth_diff_tot-n_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                    595.348458
# NORTH SEA                             6227.905182
# NORWEGIAN SEA2                        7367.288126
# SKAGERAK                             12869.205614
#
#                      accum_anth_diff_tot-p_tonnes  accum_aqu_tot-n_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                     29.007032            14140.779244
# NORTH SEA                              191.999327            19560.984224
# NORWEGIAN SEA2                         236.643940            22963.896011
# SKAGERAK                               320.197798               25.006770
#
#                      accum_aqu_tot-p_tonnes  accum_ind_tot-n_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA             2435.102449               83.270000
# NORTH SEA                       3370.099669              437.681065
# NORWEGIAN SEA2                  3971.308470             1029.588230
# SKAGERAK                           4.222934             1057.199191
#
#                      accum_ind_tot-p_tonnes  accum_nat_diff_tot-n_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA                6.071000                  8597.455425
# NORTH SEA                         93.562709                 20977.587634
# NORWEGIAN SEA2                   119.630200                 16057.491971
# SKAGERAK                          67.486975                 16386.615782
#
#                      accum_nat_diff_tot-p_tonnes  accum_q_m3/s  \
# ospar_region
# LOFOTEN-BARENTS SEA                   129.023080   2107.379728
# NORTH SEA                             201.569483   3326.954266
# NORWEGIAN SEA2                        235.914994   3230.153201
# SKAGERAK                              146.166276   2127.911199
#
#                      accum_ren_tot-n_tonnes  accum_ren_tot-p_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA              972.323096              141.231208
# NORTH SEA                       3379.521592              392.782224
# NORWEGIAN SEA2                  2602.465008              343.750027
# SKAGERAK                        8324.041575              127.213095
#
#                      accum_spr_tot-n_tonnes  accum_spr_tot-p_tonnes  \
# ospar_region
# LOFOTEN-BARENTS SEA              329.527630               40.781418
# NORTH SEA                        696.254634               81.460852
# NORWEGIAN SEA2                   716.427779               87.515367
# SKAGERAK                        1036.363378               69.405388
#
#                      accum_upstr_area_km2
# ospar_region
# LOFOTEN-BARENTS SEA             138090.89
# NORTH SEA                        59314.38
# NORWEGIAN SEA2                  113934.05
# SKAGERAK                        102574.69

# %% [markdown]
# We can now calculate the unmonitored component by simply subtracting the values modelled upstream of monitoring stations from the overall modelled inputs to each OSPAR region.

# %%
# Calc unmonitored loads
unmon_df = os_df - mon_df

# Write output
out_csv = (r'C:\Data\James_Work\Staff\Oeyvind_K\Elveovervakingsprogrammet'
           r'\NOPE\unmonitored_loads_2016.csv')
unmon_df.to_csv(out_csv, encoding='utf-8', index_label='ospar_region')

unmon_df.T
# Out:
# ospar_region                    LOFOTEN-BARENTS SEA     NORTH SEA  \
# accum_all_point_tot-n_tonnes           15458.524253  23727.341837
# accum_all_point_tot-p_tonnes            2618.378584   3903.017420
# accum_all_sources_tot-n_tonnes         20438.051437  37622.166635
# accum_all_sources_tot-p_tonnes          2720.545593   4132.681710
# accum_anth_diff_tot-n_tonnes             455.396947   3571.537484
# accum_anth_diff_tot-p_tonnes              23.747476    121.066893
# accum_aqu_tot-n_tonnes                 14140.779244  19560.984224
# accum_aqu_tot-p_tonnes                  2435.102449   3370.099669
# accum_ind_tot-n_tonnes                    83.270000    412.077221
# accum_ind_tot-p_tonnes                     6.071000     89.921536
# accum_nat_diff_tot-n_tonnes             4524.130237  10323.287314
# accum_nat_diff_tot-p_tonnes               78.419533    108.597397
# accum_q_m3/s                            1210.115874   1658.300056
# accum_ren_tot-n_tonnes                   947.675441   3146.956776
# accum_ren_tot-p_tonnes                   140.473513    368.774196
# accum_spr_tot-n_tonnes                   278.774009    562.851200
# accum_spr_tot-p_tonnes                    36.064179     70.656835
# accum_upstr_area_km2                   74535.280000  34090.850000
#
# ospar_region                    NORWEGIAN SEA2     SKAGERAK
# accum_all_point_tot-n_tonnes      26785.757349  6756.600777
# accum_all_point_tot-p_tonnes       4474.239185   165.893363
# accum_all_sources_tot-n_tonnes    38416.164974  9619.703462
# accum_all_sources_tot-p_tonnes     4742.799061   253.181964
# accum_anth_diff_tot-n_tonnes       4421.339087  1718.965133
# accum_anth_diff_tot-p_tonnes        154.604310    75.096395
# accum_aqu_tot-n_tonnes            22963.896011    25.006770
# accum_aqu_tot-p_tonnes             3971.308470     4.222934
# accum_ind_tot-n_tonnes              983.546400   875.114000
# accum_ind_tot-p_tonnes              109.186700    40.884000
# accum_nat_diff_tot-n_tonnes        7209.068538  1144.137552
# accum_nat_diff_tot-p_tonnes         113.955567    12.192206
# accum_q_m3/s                       1573.902134   106.230218
# accum_ren_tot-n_tonnes             2275.374435  5682.882775
# accum_ren_tot-p_tonnes              323.881196   102.663684
# accum_spr_tot-n_tonnes              506.461688   162.718341
# accum_spr_tot-p_tonnes               65.107328    17.319505
# accum_upstr_area_km2              64783.560000  8402.440000

# %% [markdown]
# For comparison with the previous methodology, I have extracted the loads from Table 3 of the 2015 report and added them to Excel. The code below aggregates the dataframe above into approximately the same categories used by Tore in the report. The bar charts illustrate the results obtained from the two methods. **Note the log scale on the y-axis**.

# %%
# Aggregate to match report
unmon_df['flow'] = unmon_df['accum_q_m3/s']*60*60*24/1000. # 1000s m3/day

unmon_df['sew_n'] = unmon_df['accum_ren_tot-n_tonnes'] + unmon_df['accum_spr_tot-n_tonnes']
unmon_df['sew_p'] = unmon_df['accum_ren_tot-p_tonnes'] + unmon_df['accum_spr_tot-p_tonnes']

unmon_df['ind_n'] = unmon_df['accum_ind_tot-n_tonnes']
unmon_df['ind_p'] = unmon_df['accum_ind_tot-p_tonnes']

unmon_df['fish_n'] = unmon_df['accum_aqu_tot-n_tonnes']
unmon_df['fish_p'] = unmon_df['accum_aqu_tot-p_tonnes']

unmon_df['diff_n'] = unmon_df['accum_anth_diff_tot-n_tonnes'] + unmon_df['accum_nat_diff_tot-n_tonnes']
unmon_df['diff_p'] = unmon_df['accum_anth_diff_tot-p_tonnes'] + unmon_df['accum_nat_diff_tot-p_tonnes']

new_df = unmon_df[['flow', 'sew_n', 'sew_p', 
                   'ind_n', 'ind_p', 'fish_n', 
                   'fish_p', 'diff_n', 'diff_p']]

# Total for Norway
new_df.loc['NORWAY'] = new_df.sum(axis=0)

# Reorder rows
new_df = new_df.reindex(['NORWAY', 'LOFOTEN-BARENTS SEA', 'NORTH SEA', 
                         'NORWEGIAN SEA2', 'SKAGERAK'])

new_df.astype(int).head()
# Out:
# C:\Data\WinPython-64bit-2.7.10.3\python-2.7.10.amd64\lib\site-packages\ipykernel\__main__.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                        flow  sew_n  sew_p  ind_n  ind_p  fish_n  fish_p  \
# ospar_region
# NORWAY               392994  13563   1124   2354    246   56690    9780
# LOFOTEN-BARENTS SEA  104554   1226    176     83      6   14140    2435
# NORTH SEA            143277   3709    439    412     89   19560    3370
# NORWEGIAN SEA2       135985   2781    388    983    109   22963    3971
# SKAGERAK               9178   5845    119    875     40      25       4
#
#                      diff_n  diff_p
# ospar_region
# NORWAY                33367     687
# LOFOTEN-BARENTS SEA    4979     102
# NORTH SEA             13894     229
# NORWEGIAN SEA2        11630     268
# SKAGERAK               2863      87

# %% [markdown]
# For comparison, here are the values for 2015 derived using Tore's approach and published in the 2015 report. Obviously these dataframes should not be the same, as they are for different years, but the numbers should be broadly comparable.

# %%
# Read data from report
in_xlsx = (r'C:\Data\James_Work\Staff\Oeyvind_K\Elveovervakingsprogrammet'
           r'\NOPE\unmonitored_loads_2015_report.xlsx')
old_df = pd.read_excel(in_xlsx, sheetname='2015_report', index_col=0)

old_df.head()
# Out:
#                        flow  sew_n  sew_p  ind_n  ind_p  fish_n  fish_p  \
# ospar_region
# NORWAY               478573  13527   1015   2324    191   57142    9670
# LOFOTEN-BARENTS SEA  118195   1204    163     57      4   14020    2366
# NORTH SEA            179818   3899    350    394     79   19005    3210
# NORWEGIAN SEA2       171629   2818    368    924     77   24074    4087
# SKAGERAK               8931   5606    134    949     30      43       7
#
#                      diff_n  diff_p
# ospar_region
# NORWAY                45664     830
# LOFOTEN-BARENTS SEA    7517     144
# NORTH SEA             19379     288
# NORWEGIAN SEA2        15556     319
# SKAGERAK               3212      79
